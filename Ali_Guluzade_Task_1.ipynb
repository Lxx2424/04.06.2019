# %% [markdown]
# <a href="https://colab.research.google.com/github/Lxx2424/04.06.2019/blob/master/Ali_Guluzade_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp= [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]
# Createa linearplot
plt.plot(years, gdp, color="green", marker="o", linestyle="solid")
# Addtitle.
plt.title("NominalGDP")
# Addlabels.
plt.ylabel("Bilions$")
plt.show()

# %%
import numpy as np
x = np.linspace(-1.4, 1.4, 30)
plt.plot(x, x, "g--", x, x**2, "r:", x, x**3, "b^")
plt.show()

# %%
x = np.linspace(-1.4, 1.4, 30)
plt.plot(x, x**2)
plt.savefig("my_square_function.png", transparent=True)

# %%
x = np.linspace(-1.5, 1.5, 30)
px= 0.8
py= px**2
plt.plot(x, x**2, "b-", px, py, "ro")
plt.text (0, 1.5, "Squarefunction\n$y= x^2$", fontsize=20,color='blue', horizontalalignment="center")
plt.text(px-0.08, py, "Beautifulpoint", ha="right", weight="heavy")
plt.text(px, py, "x = %0.2f\ny= %0.2f"%(px, py), rotation=50, color='gray')
plt.show()

# %%
plt.plot(x, x**2, px, py, "ro")
plt.annotate("Beautifulpoint", xy=(px, py), xytext=(px-1.3,py+0.5),color="green", weight="heavy", fontsize=14,arrowprops={"facecolor": "lightgreen"})
plt.show()

# %%
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]
#lets create a usefull indes xs:
xs= [i for i, _ in enumerate(movies)]
from matplotlib import pyplot as plt
# Draw bars:  x [xs] i wysokości [num_oscars]:
plt.bar(xs, num_oscars)
plt.ylabel("Numberof Oscars")
plt.title("My favoritemovies")
# Label the film titles on the x-axis and centre tchem:
plt.xticks([i for i, _ in enumerate(movies)], movies)
plt.show()

# %%
# import counter class from collections module
from collections import Counter
grades = [83,95,91,87,70,0,85,82,100,67,73,77,0]
decile = lambda grade: grade // 10 * 10
histogram = Counter(decile(grade) for grade in grades)
plt.bar([x for x in histogram.keys()],histogram.values(),8)
plt.axis([-5, 105, 0, 5]) 
plt.xticks([10 * i for i in range(11)])
# Putx labelsin points:  0, 10, ..., 100. labels in points: 0, 10, ..., 100.
plt.xlabel("Decyl")
plt.ylabel("Nb of students")
plt.title("Distribution of marksfrom 1st sem.")
plt.show()

# %%
#Task 4: chart_scatter_plot
# make_chart_scatter_plot
friends = [ 70, 65, 72, 63, 71, 64, 60, 64, 67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190] 
labels = ["a", "b", "c", "d", "e", "f", "g", "h", "i"]
plt.scatter(friends, minutes)

# label each point

for label, friend_count, minute_count in zip(labels, friends, minutes):
  plt.annotate(label,
    xy=(friend_count, minute_count), # put the label with its point 
    xytext=(5, -5), # but slightly offset
    textcoords="offset points")
plt.title("Daily Minutes vs. Number of Friends") 
plt.xlabel("# of friends")
plt.ylabel("daily minutes spent on the site") 
plt.show()

# %%
#make_chart_pie_chart
plt.pie([0.95, 0.05], labels=["Uses pie charts", "Knows better"])
# make sure pie is a circle and not an oval
plt.axis("equal")
plt.show()

# %%
#Task 6. Draw the course of changes (trends) on one chart :

variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x + y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]
function: plt.plot() 
plt.plot(xs, variance, 'g-', label='variance') # green solid line
plt.plot(xs, bias_squared, 'r-.', label='bias^2') # red dot + hatched line
plt.plot(xs, total_error, 'b:', label='total error') # blue dot line
# We assigned labels to all data series, # so the legend will be generated automatically.
# Parameter loc=9 places it in the middle at the top of the chart.
plt.legend(loc=9)
plt.xlabel("Degree of the model complexity")
plt.title(" Compromise between threshold value and model complexity ")
plt.show()

# %%
#Let’s prepare our functions:

from matplotlib import pyplot as plt
import random
import sys
import math

def bucketize(point, bucket_size):
    """Assign a point to the next lowest multiple bucket_size.""" 
    return bucket_size * math.floor(point / bucket_size)
def make_histogram(points, bucket_size):
    """Divides the points into groups and counts the points placed in each group""" 
    return Counter(bucketize(point, bucket_size) for point in points)
def plot_histogram(points, bucket_size, title=""):
    histogram = make_histogram(points, bucket_size) 
    plt.bar(histogram.keys(), histogram.values(), width=bucket_size) 
    plt.title(title)
    plt.show()


#let's generate two sets of data with different distributions :
import random
random.seed(0)
# Uniform distribution in the range: -100 .. 100.
uniform = [200 * random.random() - 100 for _ in range(10000)] 
plot_histogram(uniform, 10, " Uniform distribution histogram ")

# Normal distribution of mean 0 and standard deviation equal to 57. 
normal = [57 * inverse_normal_cdf(random.random())
  for _ in range(10000)]
plot_histogram(normal, 10, " Normal distribution histogram ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-0d3b65053a68> in <module>
#      28 # Normal distribution of mean 0 and standard deviation equal to 57.
#      29 normal = [57 * inverse_normal_cdf(random.random())
# ---> 30   for _ in range(10000)]
#      31 plot_histogram(normal, 10, " Normal distribution histogram ")
#
# <ipython-input-46-0d3b65053a68> in <listcomp>(.0)
#      28 # Normal distribution of mean 0 and standard deviation equal to 57.
#      29 normal = [57 * inverse_normal_cdf(random.random())
# ---> 30   for _ in range(10000)]
#      31 plot_histogram(normal, 10, " Normal distribution histogram ")
#
# NameError: name 'inverse_normal_cdf' is not defined
